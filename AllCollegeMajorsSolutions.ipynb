# %%
import pandas as pd

# %%
df = pd.read_csv("all-ages.csv")

# %%
df.head(5)
# Out:
#    Major_code                                  Major  \
# 0        1100                    GENERAL AGRICULTURE
# 1        1101  AGRICULTURE PRODUCTION AND MANAGEMENT
# 2        1102                 AGRICULTURAL ECONOMICS
# 3        1103                        ANIMAL SCIENCES
# 4        1104                           FOOD SCIENCE
#
#                     Major_category   Total  Employed  \
# 0  Agriculture & Natural Resources  128148     90245
# 1  Agriculture & Natural Resources   95326     76865
# 2  Agriculture & Natural Resources   33955     26321
# 3  Agriculture & Natural Resources  103549     81177
# 4  Agriculture & Natural Resources   24280     17281
#
#    Employed_full_time_year_round  Unemployed  Unemployment_rate  Median  \
# 0                          74078        2423           0.026147   50000
# 1                          64240        2266           0.028636   54000
# 2                          22810         821           0.030248   63000
# ...

# %%
MC = df["Major_code"]
M = df["Major"]
MC2 = df["Major_category"]
T = df["Total"]

# %%
MC.head()
# Out:
# 0    1100
# 1    1101
# 2    1102
# 3    1103
# 4    1104
# Name: Major_code, dtype: int64

# %%
M.head()
# Out:
# 0                      GENERAL AGRICULTURE
# 1    AGRICULTURE PRODUCTION AND MANAGEMENT
# 2                   AGRICULTURAL ECONOMICS
# 3                          ANIMAL SCIENCES
# 4                             FOOD SCIENCE
# Name: Major, dtype: object

# %%
MC2.head()
# Out:
# 0    Agriculture & Natural Resources
# 1    Agriculture & Natural Resources
# 2    Agriculture & Natural Resources
# 3    Agriculture & Natural Resources
# 4    Agriculture & Natural Resources
# Name: Major_category, dtype: object

# %%
T.head()
# Out:
# 0    128148
# 1     95326
# 2     33955
# 3    103549
# 4     24280
# Name: Total, dtype: int64

# %%
MC.describe()
# Out:
# count     173.000000
# mean     3879.815029
# std      1687.753140
# min      1100.000000
# 25%      2403.000000
# 50%      3608.000000
# 75%      5503.000000
# max      6403.000000
# Name: Major_code, dtype: float64

# %%
M.describe()
# Out:
# count                                    173
# unique                                   173
# top       INDUSTRIAL PRODUCTION TECHNOLOGIES
# freq                                       1
# Name: Major, dtype: object

# %%
MC2.describe()
# Out:
# count             173
# unique             16
# top       Engineering
# freq               29
# Name: Major_category, dtype: object

# %%
T.describe()
# Out:
# count    1.730000e+02
# mean     2.302566e+05
# std      4.220685e+05
# min      2.396000e+03
# 25%      2.428000e+04
# 50%      7.579100e+04
# 75%      2.057630e+05
# max      3.123510e+06
# Name: Total, dtype: float64

# %%
df.mean()
# Out:
# Major_code                         3879.815029
# Total                            230256.635838
# Employed                         166161.982659
# Employed_full_time_year_round    126307.774566
# Unemployed                         9725.034682
# Unemployment_rate                     0.057355
# Median                            56816.184971
# P25th                             38697.109827
# P75th                             82506.358382
# dtype: float64

# %%
df.corr()
# Out:
#                                Major_code     Total  Employed  \
# Major_code                       1.000000  0.182376  0.196165
# Total                            0.182376  1.000000  0.994976
# Employed                         0.196165  0.994976  1.000000
# Employed_full_time_year_round    0.195620  0.984676  0.995810
# Unemployed                       0.204887  0.962231  0.969786
# Unemployment_rate                0.228506 -0.066473 -0.063512
# Median                          -0.154187 -0.034050 -0.017141
# P25th                           -0.150808 -0.007415  0.007938
# P75th                           -0.099837 -0.019955 -0.000463
#
#                                Employed_full_time_year_round  Unemployed  \
# Major_code                                          0.195620    0.204887
# Total                                               0.984676    0.962231
# Employed                                            0.995810    0.969786
# ...

# %%
df.count()
# Out:
# Major_code                       173
# Major                            173
# Major_category                   173
# Total                            173
# Employed                         173
# Employed_full_time_year_round    173
# Unemployed                       173
# Unemployment_rate                173
# Median                           173
# P25th                            173
# P75th                            173
# dtype: int64

# %%
df.max()
# Out:
# Major_code                                 6403
# Major                                   ZOOLOGY
# Major_category                   Social Science
# Total                                   3123510
# Employed                                2354398
# Employed_full_time_year_round           1939384
# Unemployed                               147261
# Unemployment_rate                      0.156147
# Median                                   125000
# P25th                                     78000
# P75th                                    210000
# dtype: object

# %%
df.min()
# Out:
# Major_code                                                  1100
# Major                                                 ACCOUNTING
# Major_category                   Agriculture & Natural Resources
# Total                                                       2396
# Employed                                                    1492
# Employed_full_time_year_round                               1093
# Unemployed                                                     0
# Unemployment_rate                                              0
# Median                                                     35000
# P25th                                                      24900
# P75th                                                      45800
# dtype: object

# %%
df.median()
# Out:
# Major_code                        3608.000000
# Total                            75791.000000
# Employed                         56564.000000
# Employed_full_time_year_round    39613.000000
# Unemployed                        3619.000000
# Unemployment_rate                    0.054719
# Median                           53000.000000
# P25th                            36000.000000
# P75th                            80000.000000
# dtype: float64

# %%
df.std()
# Out:
# Major_code                         1687.753140
# Total                            422068.483149
# Employed                         307324.399668
# Employed_full_time_year_round    242425.389073
# Unemployed                        18022.040192
# Unemployment_rate                     0.019177
# Median                            14706.226865
# P25th                              9414.524761
# P75th                             20805.330126
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 11 columns):
# Major_code                       173 non-null int64
# Major                            173 non-null object
# Major_category                   173 non-null object
# Total                            173 non-null int64
# Employed                         173 non-null int64
# Employed_full_time_year_round    173 non-null int64
# Unemployed                       173 non-null int64
# Unemployment_rate                173 non-null float64
# Median                           173 non-null int64
# P25th                            173 non-null int64
# P75th                            173 non-null float64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 14.9+ KB

# %%
s.values_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-c664fa2bd491> in <module>()
# ----> 1 s.values_counts(dropna=False)
#
# NameError: name 's' is not defined

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Major_code                                              Major  \
# 0          1100                                GENERAL AGRICULTURE
# 1          1101              AGRICULTURE PRODUCTION AND MANAGEMENT
# 2          1102                             AGRICULTURAL ECONOMICS
# 3          1103                                    ANIMAL SCIENCES
# 4          1104                                       FOOD SCIENCE
# 5          1105                         PLANT SCIENCE AND AGRONOMY
# 6          1106                                       SOIL SCIENCE
# 7          1199                          MISCELLANEOUS AGRICULTURE
# 8          1301                              ENVIRONMENTAL SCIENCE
# 9          1302                                           FORESTRY
# 10         1303                       NATURAL RESOURCES MANAGEMENT
# 11         1401                                       ARCHITECTURE
# ...

# %%
df[df["Total"] > 1984]
# Out:
#      Major_code                                              Major  \
# 0          1100                                GENERAL AGRICULTURE
# 1          1101              AGRICULTURE PRODUCTION AND MANAGEMENT
# 2          1102                             AGRICULTURAL ECONOMICS
# 3          1103                                    ANIMAL SCIENCES
# 4          1104                                       FOOD SCIENCE
# 5          1105                         PLANT SCIENCE AND AGRONOMY
# 6          1106                                       SOIL SCIENCE
# 7          1199                          MISCELLANEOUS AGRICULTURE
# 8          1301                              ENVIRONMENTAL SCIENCE
# 9          1302                                           FORESTRY
# 10         1303                       NATURAL RESOURCES MANAGEMENT
# 11         1401                                       ARCHITECTURE
# 12         1501               AREA ETHNIC AND CIVILIZATION STUDIES
# ...

# %%
df.sort_values("Major_code")
# Out:
#      Major_code                                              Major  \
# 0          1100                                GENERAL AGRICULTURE
# 1          1101              AGRICULTURE PRODUCTION AND MANAGEMENT
# 2          1102                             AGRICULTURAL ECONOMICS
# 3          1103                                    ANIMAL SCIENCES
# 4          1104                                       FOOD SCIENCE
# 5          1105                         PLANT SCIENCE AND AGRONOMY
# 6          1106                                       SOIL SCIENCE
# 7          1199                          MISCELLANEOUS AGRICULTURE
# 8          1301                              ENVIRONMENTAL SCIENCE
# 9          1302                                           FORESTRY
# 10         1303                       NATURAL RESOURCES MANAGEMENT
# 11         1401                                       ARCHITECTURE
# 12         1501               AREA ETHNIC AND CIVILIZATION STUDIES
# ...

# %%
df.sort_values("Major",ascending=False)
# Out:
#      Major_code                                          Major  \
# 87         3609                                        ZOOLOGY
# 141        6003                     VISUAL AND PERFORMING ARTS
# 172        6403                          UNITED STATES HISTORY
# 155        6109                  TREATMENT THERAPY PROFESSIONS
# 137        5901       TRANSPORTATION SCIENCES AND TECHNOLOGIES
# 102        4901               THEOLOGY AND RELIGIOUS VOCATIONS
# 36         2312             TEACHER EDUCATION: MULTIPLE LEVELS
# 145        6007                                    STUDIO ARTS
# 92         3702                STATISTICS AND DECISION SCIENCE
# 34         2310                        SPECIAL NEEDS EDUCATION
# 6          1106                                   SOIL SCIENCE
# 133        5507                                      SOCIOLOGY
# 125        5404                                    SOCIAL WORK
# 35         2311    SOCIAL SCIENCE OR HISTORY TEACHER EDUCATION
# ...

# %%
df["Total"].mean
# Out:
# <bound method Series.mean of 0       128148
# 1        95326
# 2        33955
# 3       103549
# 4        24280
# 5        79409
# 6         6586
# 7         8549
# 8       106106
# 9        69447
# 10       83188
# 11      294692
# 12      103740
# 13      987676
# 14      418104
# 15      211213
# 16      186829
# 17       62141
# 18      253782
# 19       29317
# 20      783292
# 21       77805
# 22       39362
# 23       51771
# 24       42325
# 25     1438867
# 26        4037
# 27        2396
# 28     1446701
# 29       68808
#         ...
# 143     133508
# 144      90852
# 145      81008
# 146       8511
# 147     104516
# 148      74977
# 149     108510
# 150      64316
# 151     164990
# 152      32514
# 153    1769892
# 154     180084
# 155     252138
# 156      56741
# 157      77647
# 158    2148712
# 159    1779219
# 160       9763
# 161    3123510
# 162      57200
# 163      75547
# 164    1114624
# 165     816548
# 166     187274
# 167      86064
# 168     200854
# ...

# %%
total = df["Total"]

# %%
got_jobs = df["Employed"]

# %%
plt.scatter(total, got_jobs, color = "blue")
plt.title("Total vs Employees who got a job ")
plt.ylabel("Employed")
plt.xlabel("Total")
plt.xlim(0,1300000)
plt.ylim(0,1000000)
plt.show()
plt.savefig("I_finally_got_it_:)")
